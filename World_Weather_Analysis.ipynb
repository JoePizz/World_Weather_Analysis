# %%
import pandas as pad
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.8233102, -76.89176677, -61.13376282]
coordinates = zip(x,y,)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.8233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/joepizz/opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/joepizz/opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
                             citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# fort-shevchenko kz
# nanortalik gl
# ilulissat gl
# richards bay za
# longyearbyen sj
# saskylakh ru
# tiksi ru
# punta arenas cl
# saint-philippe re
# port hardy ca
# namibe ao
# wad rawah sd
# rungata ki
# cabo san lucas mx
# kodiak us
# tsihombe mg
# kaitangata nz
# puerto quijarro bo
# bacuit ph
# punta arenas cl
# puerto ayora ec
# mildura au
# torbay ca
# yagodnoye ru
# faanui pf
# arona es
# barrow us
# clyde river ca
# mar del plata ar
# matay eg
# west bay ky
# puerto ayora ec
# butaritari ki
# villazon bo
# nikolskoye ru
# cururupu br
# busselton au
# torbay ca
# ushuaia ar
# illoqqortoormiut gl
# mahadday weyne so
# taolanaro mg
# san ramon de la nueva oran ar
# saint-philippe re
# cape town za
# kaitangata nz
# seuzach ch
# hermanus za
# qaanaaq gl
# belushya guba ru
# rikitea pf
# zalantun cn
# turan ru
# cape town za
# ninghai cn
# longyearbyen sj
# hilo us
# leningradskiy ru
# burnie au
# kapaa us
# tsihombe mg
# hermanus za
# upernavik gl
# vila franca do campo pt
# mar del plata ar
# nyurba ru
# chokurdakh ru
# yellowknife ca
# hobart au
# ushuaia ar
# ushuaia ar
# los llanos de aridane es
# vostok ru
# mataura pf
# atuona pf
# punta arenas cl
# rikitea pf
# victoria sc
# mount pleasant us
# pipar in
# arraial do cabo br
# waounde sn
# kotri pk
# vestmannaeyjar is
# skibbereen ie
# atuona pf
# vysokogornyy ru
# taolanaro mg
# rikitea pf
# zeya ru
# ushuaia ar
# qaanaaq gl
# kalmunai lk
# arkansas city us
# baykit ru
# port alfred za
# heide de
# rock springs us
# haines junction ca
# cape town za
# tambovka ru
# severo-kurilsk ru
# ushuaia ar
# kapaa us
# albany au
# bluff nz
# barrow us
# college us
# katsuura jp
# pecos us
# muriti tz
# new norfolk au
# hithadhoo mv
# krasnotorka ua
# kangaatsiaq gl
# clyde river ca
# matara lk
# umzimvubu za
# bluff nz
# taolanaro mg
# albany au
# tokmak kg
# avarua ck
# rajauri in
# vaini to
# hobart au
# rawson ar
# new norfolk au
# severo-kurilsk ru
# georgetown sh
# mataura pf
# mar del plata ar
# harper lr
# bengkulu id
# samusu ws
# taolanaro mg
# dikson ru
# santa cruz cr
# sabha ly
# busselton au
# albany au
# cockburn town bs
# fortuna us
# pevek ru
# tezu in
# san javier bo
# barrow us
# sarkand kz
# vaini to
# hithadhoo mv
# valparaiso cl
# norman wells ca
# kavieng pg
# albany au
# synya ru
# new norfolk au
# punta arenas cl
# avarua ck
# dikson ru
# avarua ck
# barrow us
# avarua ck
# asyut eg
# mehamn no
# monroe us
# tasiilaq gl
# ushuaia ar
# taolanaro mg
# hervey bay au
# marystown ca
# chiang klang th
# jamestown sh
# kavieng pg
# jamestown sh
# mayo ca
# lasa cn
# upernavik gl
# koutsouras gr
# tasiilaq gl
# thompson ca
# atuona pf
# taolanaro mg
# atuona pf
# neryungri ru
# mercedes ar
# kruisfontein za
# tiksi ru
# kununurra au
# namibe ao
# punta arenas cl
# albany au
# castro cl
# winslow us
# albany au
# henderson us
# busselton au
# barrow us
# avera pf
# oistins bb
# san patricio mx
# salalah om
# juba sd
# sao bras de alportel pt
# emmett us
# dikson ru
# atuona pf
# barrow us
# lompoc us
# cape town za
# kavaratti in
# port keats au
# jamestown sh
# abalak ne
# lorengau pg
# petatlan mx
# longyearbyen sj
# hobart au
# rikitea pf
# arkhangelsk ru
# genhe cn
# charagua bo
# dikson ru
# carnarvon au
# mataura pf
# charlottesville us
# bowen au
# puerto ayora ec
# bongandanga cd
# novobirilyussy ru
# qaanaaq gl
# rikitea pf
# saint-augustin ca
# mataura pf
# dikson ru
# chuy uy
# ushuaia ar
# chama zm
# san patricio mx
# punta arenas cl
# taolanaro mg
# vavuniya lk
# maceio br
# atuona pf
# rikitea pf
# bluff nz
# barrow us
# middlebury us
# chokurdakh ru
# rikitea pf
# pacific grove us
# jabiru au
# mataura pf
# portales us
# atuona pf
# yongan cn
# nizhneyansk ru
# saldanha za
# mataura pf
# rio bueno cl
# sitka us
# alberton ca
# qaanaaq gl
# alofi nu
# taolanaro mg
# thompson ca
# reidsville us
# tuktoyaktuk ca
# aksarka ru
# kieta pg
# filingue ne
# rikitea pf
# hasaki jp
# butaritari ki
# qasigiannguit gl
# antofagasta cl
# pangpang ph
# ribeira grande pt
# mahebourg mu
# arraial do cabo br
# ribeira grande pt
# bredasdorp za
# dwarka in
# ilulissat gl
# cape town za
# venado tuerto ar
# albany au
# laukaa fi
# busselton au
# bredasdorp za
# tupik ru
# mataura pf
# port elizabeth za
# hilo us
# avarua ck
# avarua ck
# katsuura jp
# ushuaia ar
# husavik is
# oktyabrskoye ru
# cabedelo br
# giyani za
# zhigansk ru
# vaitupu wf
# narsaq gl
# boguchany ru
# sitka us
# ushuaia ar
# airai pw
# camacha pt
# gao ml
# belushya guba ru
# mar del plata ar
# punta arenas cl
# lorengau pg
# grindavik is
# punta arenas cl
# camacha pt
# yenagoa ng
# ribeira grande pt
# punta arenas cl
# grand river south east mu
# senanga zm
# kapaa us
# grong no
# mackay au
# pevek ru
# sarangani ph
# rikitea pf
# cape town za
# bambous virieux mu
# hobart au
# ribeira grande pt
# kapaa us
# rikitea pf
# alugan ph
# longyearbyen sj
# bethel us
# georgetown sh
# puerto ayora ec
# banmo mm
# steinbach ca
# rikitea pf
# rikitea pf
# viransehir tr
# fortuna us
# lata sb
# shimoda jp
# puerto ayora ec
# busselton au
# kaitangata nz
# new norfolk au
# iqaluit ca
# jamestown sh
# sentyabrskiy ru
# busselton au
# nelson bay au
# thinadhoo mv
# hobart au
# new norfolk au
# tuktoyaktuk ca
# nanning cn
# illoqqortoormiut gl
# ushuaia ar
# fairbanks us
# punta arenas cl
# bredasdorp za
# carora ve
# jamestown sh
# albany au
# watertown us
# barrow us
# east london za
# taolanaro mg
# gangotri in
# qaanaaq gl
# bengkulu id
# aripuana br
# pokanayevka ru
# port elizabeth za
# puerto ayora ec
# rikitea pf
# upernavik gl
# belushya guba ru
# kiruna se
# les cayes ht
# albany au
# ushuaia ar
# nome us
# taolanaro mg
# saint-philippe re
# rikitea pf
# shuya ru
# saint-philippe re
# port blair in
# saleaula ws
# punta arenas cl
# grand gaube mu
# rikitea pf
# mataura pf
# berkak no
# broome au
# golubitskaya ru
# puerto ayora ec
# mocuba mz
# qovlar az
# sataua ws
# vaini to
# lebu cl
# mayachnyy ru
# esperance au
# vaini to
# paamiut gl
# tuktoyaktuk ca
# esperance au
# castro cl
# haines junction ca
# iqaluit ca
# lodja cd
# ushuaia ar
# cheyenne us
# talnakh ru
# lodja cd
# adrar dz
# bluff nz
# ginda er
# jamestown sh
# tasiilaq gl
# hithadhoo mv
# vaini to
# plasencia es
# mar del plata ar
# kununurra au
# taolanaro mg
# joacaba br
# tiksi ru
# kavieng pg
# punta arenas cl
# luderitz na
# komsomolskiy ru
# cape town za
# ban nahin la
# isiolo ke
# naze jp
# bonavista ca
# vorotynets ru
# ushuaia ar
# pevek ru
# rondonopolis br
# robore bo
# punta arenas cl
# illoqqortoormiut gl
# provideniya ru
# fort frances ca
# rikitea pf
# los llanos de aridane es
# ushuaia ar
# mataura pf
# bor cz
# puerto ayora ec
# mataura pf
# hermanus za
# new norfolk au
# lagoa pt
# new norfolk au
# shijak al
# qostanay kz
# damghan ir
# tuljapur in
# north platte us
# yellowknife ca
# tazmalt dz
# kawalu id
# busselton au
# moose factory ca
# ambon id
# lompoc us
# punta arenas cl
# esperance au
# punta arenas cl
# nizhneyansk ru
# new norfolk au
# belushya guba ru
# rikitea pf
# kodiak us
# tasiilaq gl
# rikitea pf
# cairns au
# ewa beach us
# ancud cl
# rikitea pf
# la palma pa
# cape town za
# yulara au
# virginia beach us
# ponta do sol cv
# mataura pf
# busselton au
# shellbrook ca
# puerto ayora ec
# gualaquiza ec
# albany au
# mataura pf
# georgetown sh
# puerto ayora ec
# nizhneyansk ru
# rikitea pf
# la palma pa
# butaritari ki
# punta arenas cl
# barentsburg sj
# geraldton au
# albany au
# mayo ca
# hermanus za
# tiksi ru
# tera ne
# vaitupu wf
# kapaa us
# tura ru
# atuona pf
# alma us
# rikitea pf
# attawapiskat ca
# chicama pe
# dunedin nz
# sept-iles ca
# hermanus za
# port alfred za
# vila velha br
# mendi et
# puerto ayora ec
# mataura pf
# katobu id
# ushuaia ar
# ushuaia ar
# puerto ayora ec
# manta ec
# cherskiy ru
# illoqqortoormiut gl
# imbituba br
# shache cn
# avera pf
# itaueira br
# bocas del toro pa
# tiksi ru
# fairbanks us
# castro cl
# bluff nz
# innisfail au
# stromness gb
# hithadhoo mv
# vaitupu wf
# torbay ca
# faanui pf
# bom jardim br
# upernavik gl
# yellowknife ca
# rikitea pf
# helsinki fi
# illoqqortoormiut gl
# punta arenas cl
# hofn is
# jamame so
# nguiu au
# port alfred za
# victoria sc
# busselton au
# rikitea pf
# vestmannaeyjar is
# ponta do sol cv
# bengkulu id
# cidreira br
# barrow us
# bara sd
# ushuaia ar
# llanes es
# vaini to
# dzaoudzi yt
# kapaa us
# dauphin ca
# kyra ru
# castro cl
# hasaki jp
# mataura pf
# busselton au
# busselton au
# ushuaia ar
# severo-kurilsk ru
# susanville us
# straumen no
# pueblo us
# jamestown sh
# rikitea pf
# milkovo ru
# graham us
# hervey bay au
# constitucion mx
# grand river south east mu
# nobeoka jp
# bambous virieux mu
# taolanaro mg
# dunedin nz
# busselton au
# binabalian ph
# qaanaaq gl
# castro cl
# la palma pa
# moussoro td
# harer et
# qaanaaq gl
# mendoza ar
# jamestown sh
# singaraja id
# hilo us
# punta arenas cl
# vysokogornyy ru
# punta arenas cl
# hermanus za
# tasiilaq gl
# bluff nz
# hobart au
# rikitea pf
# matadi cd
# tuktoyaktuk ca
# brus laguna hn
# sao filipe cv
# iqaluit ca
# antofagasta cl
# nome us
# mataura pf
# thompson ca
# albany au
# biak id
# marcona pe
# atuona pf
# nakamura jp
# vostok ru
# ngunguru nz
# severo-kurilsk ru
# punta arenas cl
# atikokan ca
# longyearbyen sj
# coolum beach au
# albany au
# cape coast gh
# castro cl
# warren us
# havre-saint-pierre ca
# lebu cl
# norman wells ca
# amderma ru
# port augusta au
# kapaa us
# punta arenas cl
# yukamenskoye ru
# saint-francois gp
# yellowknife ca
# illoqqortoormiut gl
# new norfolk au
# nishihara jp
# dikson ru
# norman wells ca
# jizan sa
# sola vu
# kletnya ru
# tawnat ma
# tura ru
# wulanhaote cn
# bluff nz
# mys shmidta ru
# gat ly
# cidreira br
# belushya guba ru
# yurimaguas pe
# hakvik no
# ushuaia ar
# hithadhoo mv
# bluff nz
# xaxim br
# albany au
# ushuaia ar
# ribeira grande pt
# clyde river ca
# port elizabeth za
# cape town za
# san quintin mx
# berlevag no
# ushuaia ar
# belushya guba ru
# esperance au
# haibowan cn
# atuona pf
# half moon bay us
# saskylakh ru
# portland au
# kuytun cn
# labutta mm
# bengkulu id
# barentsburg sj
# cape town za
# barrow us
# lasa cn
# kahului us
# carnarvon au
# georgetown sh
# kazalinsk kz
# alofi nu
# bluff nz
# illoqqortoormiut gl
# yellowknife ca
# ayan ru
# busselton au

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 618

# %%
print(cities)
# Out:
# ['fort-shevchenko', 'nanortalik', 'ilulissat', 'richards bay', 'longyearbyen', 'saskylakh', 'tiksi', 'punta arenas', 'saint-philippe', 'port hardy', 'namibe', 'wad rawah', 'rungata', 'cabo san lucas', 'kodiak', 'tsihombe', 'kaitangata', 'puerto quijarro', 'bacuit', 'puerto ayora', 'mildura', 'torbay', 'yagodnoye', 'faanui', 'arona', 'barrow', 'clyde river', 'mar del plata', 'matay', 'west bay', 'butaritari', 'villazon', 'nikolskoye', 'cururupu', 'busselton', 'ushuaia', 'illoqqortoormiut', 'mahadday weyne', 'taolanaro', 'san ramon de la nueva oran', 'cape town', 'seuzach', 'hermanus', 'qaanaaq', 'belushya guba', 'rikitea', 'zalantun', 'turan', 'ninghai', 'hilo', 'leningradskiy', 'burnie', 'kapaa', 'upernavik', 'vila franca do campo', 'nyurba', 'chokurdakh', 'yellowknife', 'hobart', 'los llanos de aridane', 'vostok', 'mataura', 'atuona', 'victoria', 'mount pleasant', 'pipar', 'arraial do cabo', 'waounde', 'kotri', 'vestmannaeyjar', 'skibbereen', 'vysokogornyy', 'zeya', 'kalmunai', 'arkansas city', 'baykit', 'port alfred', 'heide', 'rock springs', 'haines junction', 'tambovka', 'severo-kurilsk', 'albany', 'bluff', 'college', 'katsuura', 'pecos', 'muriti', 'new norfolk', 'hithadhoo', 'krasnotorka', 'kangaatsiaq', 'matara', 'umzimvubu', 'tokmak', 'avarua', 'rajauri', 'vaini', 'rawson', 'georgetown', 'harper', 'bengkulu', 'samusu', 'dikson', 'santa cruz', 'sabha', 'cockburn town', 'fortuna', 'pevek', 'tezu', 'san javier', 'sarkand', 'valparaiso', 'norman wells', 'kavieng', 'synya', 'asyut', 'mehamn', 'monroe', 'tasiilaq', 'hervey bay', 'marystown', 'chiang klang', 'jamestown', 'mayo', 'lasa', 'koutsouras', 'thompson', 'neryungri', 'mercedes', 'kruisfontein', 'kununurra', 'castro', 'winslow', 'henderson', 'avera', 'oistins', 'san patricio', 'salalah', 'juba', 'sao bras de alportel', 'emmett', 'lompoc', 'kavaratti', 'port keats', 'abalak', 'lorengau', 'petatlan', 'arkhangelsk', 'genhe', 'charagua', 'carnarvon', 'charlottesville', 'bowen', 'bongandanga', 'novobirilyussy', 'saint-augustin', 'chuy', 'chama', 'vavuniya', 'maceio', 'middlebury', 'pacific grove', 'jabiru', 'portales', 'yongan', 'nizhneyansk', 'saldanha', 'rio bueno', 'sitka', 'alberton', 'alofi', 'reidsville', 'tuktoyaktuk', 'aksarka', 'kieta', 'filingue', 'hasaki', 'qasigiannguit', 'antofagasta', 'pangpang', 'ribeira grande', 'mahebourg', 'bredasdorp', 'dwarka', 'venado tuerto', 'laukaa', 'tupik', 'port elizabeth', 'husavik', 'oktyabrskoye', 'cabedelo', 'giyani', 'zhigansk', 'vaitupu', 'narsaq', 'boguchany', 'airai', 'camacha', 'gao', 'grindavik', 'yenagoa', 'grand river south east', 'senanga', 'mitu', 'tessalit', 'goundi', 'victor harbor', 'east london', 'flinders', 'pisco', 'komsomolskiy', 'barcelos', 'tumpat', 'sicamous', 'manono', 'barentu', 'garca', 'nagapattinam', 'carmen', 'nantucket', 'mitsamiouli', 'lebu', 'bam', 'saint anthony', 'loa janan', 'ngukurr', 'harnosand', 'bethel', 'borda da mata', 'reyes', 'nowa sol', 'santander', 'bahia de caraquez', 'talaya', 'kharp', 'aflu', 'port victoria', 'pokhara', 'attawapiskat', 'wajima', 'angoche', 'beihai', 'kasongo-lunda', 'gigante', 'paita', 'aykhal', 'salinas', 'cherskiy', 'waingapu', 'novyy urengoy', 'besikduzu', 'souillac', 'krasnoselkup', 'lazaro cardenas', 'nyakahanga', 'svetlogorsk', 'codrington', 'sola', 'capitan bado', 'kafue', 'keti bandar', 'roald', 'axim', 'serov', 'port hedland', 'chernaya kholunitsa', 'tokur', 'worland', 'pringsewu', 'plettenberg bay', 'yulara', 'katherine', 'lieksa', 'berlevag', 'mansa', 'esperance', 'kenai', 'bolanos de calatrava', 'barentsburg', 'grong', 'mackay', 'sarangani', 'bambous virieux', 'alugan', 'banmo', 'steinbach', 'viransehir', 'lata', 'shimoda', 'iqaluit', 'sentyabrskiy', 'nelson bay', 'thinadhoo', 'nanning', 'fairbanks', 'carora', 'watertown', 'gangotri', 'aripuana', 'pokanayevka', 'kiruna', 'les cayes', 'nome', 'shuya', 'port blair', 'saleaula', 'grand gaube', 'berkak', 'broome', 'golubitskaya', 'mocuba', 'qovlar', 'sataua', 'mayachnyy', 'paamiut', 'lodja', 'cheyenne', 'taln ...

# %%
# Import the requests library.
import requests
# Import the API Key.
import config

# %%
from config import weather_api_key

# %%
import requests
from config_copy import API_weather

# %%
# Starting URL for Weather Map API Call.
URL = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_weather
print(URL)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d5f365fbea14123356d30c64071da89

# %%
city_url3 = URL + "&q=" + "Boston"
print(city_url3)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d5f365fbea14123356d30c64071da89&q=Boston

# %%
import requests
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = URL + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = URL + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 13 | fort-shevchenko
# Processing Record 2 of Set 13 | nanortalik
# Processing Record 3 of Set 13 | ilulissat
# Processing Record 4 of Set 13 | richards bay
# Processing Record 5 of Set 13 | longyearbyen
# Processing Record 6 of Set 13 | saskylakh
# Processing Record 7 of Set 13 | tiksi
# Processing Record 8 of Set 13 | punta arenas
# Processing Record 9 of Set 13 | saint-philippe
# Processing Record 10 of Set 13 | port hardy
# Processing Record 11 of Set 13 | namibe
# Processing Record 12 of Set 13 | wad rawah
# Processing Record 13 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 13 | cabo san lucas
# Processing Record 15 of Set 13 | kodiak
# Processing Record 16 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 13 | kaitangata
# Processing Record 18 of Set 13 | puerto quijarro
# Processing Record 19 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 20 of Set 13 | puerto ayora
# Processing Record 21 of Set 13 | mildura
# Processing Record 22 of Set 13 | torbay
# Processing Record 23 of Set 13 | yagodnoye
# Processing Record 24 of Set 13 | faanui
# Processing Record 25 of Set 13 | arona
# Processing Record 26 of Set 13 | barrow
# Processing Record 27 of Set 13 | clyde river
# Processing Record 28 of Set 13 | mar del plata
# Processing Record 29 of Set 13 | matay
# Processing Record 30 of Set 13 | west bay
# Processing Record 31 of Set 13 | butaritari
# Processing Record 32 of Set 13 | villazon
# Processing Record 33 of Set 13 | nikolskoye
# Processing Record 34 of Set 13 | cururupu
# Processing Record 35 of Set 13 | busselton
# Processing Record 36 of Set 13 | ushuaia
# Processing Record 37 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 39 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 13 | san ramon de la nueva oran
# Processing Record 41 of Set 13 | cape town
# Processing Record 42 of Set 13 | seuzach
# Processing Record 43 of Set 13 | hermanus
# Processing Record 44 of Set 13 | qaanaaq
# Processing Record 45 of Set 13 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 13 | rikitea
# Processing Record 47 of Set 13 | zalantun
# Processing Record 48 of Set 13 | turan
# Processing Record 49 of Set 13 | ninghai
# Processing Record 50 of Set 13 | hilo
# Processing Record 1 of Set 14 | leningradskiy
# Processing Record 2 of Set 14 | burnie
# Processing Record 3 of Set 14 | kapaa
# Processing Record 4 of Set 14 | upernavik
# Processing Record 5 of Set 14 | vila franca do campo
# Processing Record 6 of Set 14 | nyurba
# Processing Record 7 of Set 14 | chokurdakh
# Processing Record 8 of Set 14 | yellowknife
# Processing Record 9 of Set 14 | hobart
# Processing Record 10 of Set 14 | los llanos de aridane
# Processing Record 11 of Set 14 | vostok
# Processing Record 12 of Set 14 | mataura
# Processing Record 13 of Set 14 | atuona
# Processing Record 14 of Set 14 | victoria
# Processing Record 15 of Set 14 | mount pleasant
# Processing Record 16 of Set 14 | pipar
# Processing Record 17 of Set 14 | arraial do cabo
# Processing Record 18 of Set 14 | waounde
# Processing Record 19 of Set 14 | kotri
# Processing Record 20 of Set 14 | vestmannaeyjar
# Processing Record 21 of Set 14 | skibbereen
# Processing Record 22 of Set 14 | vysokogornyy
# Processing Record 23 of Set 14 | zeya
# Processing Record 24 of Set 14 | kalmunai
# Processing Record 25 of Set 14 | arkansas city
# Processing Record 26 of Set 14 | baykit
# Processing Record 27 of Set 14 | port alfred
# Processing Record 28 of Set 14 | heide
# Processing Record 29 of Set 14 | rock springs
# Processing Record 30 of Set 14 | haines junction
# Processing Record 31 of Set 14 | tambovka
# Processing Record 32 of Set 14 | severo-kurilsk
# Processing Record 33 of Set 14 | albany
# Processing Record 34 of Set 14 | bluff
# Processing Record 35 of Set 14 | college
# Processing Record 36 of Set 14 | katsuura
# Processing Record 37 of Set 14 | pecos
# Processing Record 38 of Set 14 | muriti
# Processing Record 39 of Set 14 | new norfolk
# Processing Record 40 of Set 14 | hithadhoo
# Processing Record 41 of Set 14 | krasnotorka
# Processing Record 42 of Set 14 | kangaatsiaq
# Processing Record 43 of Set 14 | matara
# Processing Record 44 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 14 | tokmak
# Processing Record 46 of Set 14 | avarua
# Processing Record 47 of Set 14 | rajauri
# Processing Record 48 of Set 14 | vaini
# Processing Record 49 of Set 14 | rawson
# Processing Record 50 of Set 14 | georgetown
# Processing Record 1 of Set 15 | harper
# Processing Record 2 of Set 15 | bengkulu
# Processing Record 3 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 15 | dikson
# Processing Record 5 of Set 15 | santa cruz
# Processing Record 6 of Set 15 | sabha
# Processing Record 7 of Set 15 | cockburn town
# Processing Record 8 of Set 15 | fortuna
# Processing Record 9 of Set 15 | pevek
# Processing Record 10 of Set 15 | tezu
# Processing Record 11 of Set 15 | san javier
# Processing Record 12 of Set 15 | sarkand
# Processing Record 13 of Set 15 | valparaiso
# Processing Record 14 of Set 15 | norman wells
# Processing Record 15 of Set 15 | kavieng
# Processing Record 16 of Set 15 | synya
# Processing Record 17 of Set 15 | asyut
# Processing Record 18 of Set 15 | mehamn
# Processing Record 19 of Set 15 | monroe
# Processing Record 20 of Set 15 | tasiilaq
# Processing Record 21 of Set 15 | hervey bay
# Processing Record 22 of Set 15 | marystown
# Processing Record 23 of Set 15 | chiang klang
# Processing Record 24 of Set 15 | jamestown
# Processing Record 25 of Set 15 | mayo
# Processing Record 26 of Set 15 | lasa
# Processing Record 27 of Set 15 | koutsouras
# Processing Record 28 of Set 15 | thompson
# Processing Record 29 of Set 15 | neryungri
# Processing Record 30 of Set 15 | mercedes
# Processing Record 31 of Set 15 | kruisfontein
# Processing Record 32 of Set 15 | kununurra
# Processing Record 33 of Set 15 | castro
# Processing Record 34 of Set 15 | winslow
# Processing Record 35 of Set 15 | henderson
# Processing Record 36 of Set 15 | avera
# Processing Record 37 of Set 15 | oistins
# Processing Record 38 of Set 15 | san patricio
# Processing Record 39 of Set 15 | salalah
# Processing Record 40 of Set 15 | juba
# Processing Record 41 of Set 15 | sao bras de alportel
# Processing Record 42 of Set 15 | emmett
# Processing Record 43 of Set 15 | lompoc
# Processing Record 44 of Set 15 | kavaratti
# Processing Record 45 of Set 15 | port keats
# Processing Record 46 of Set 15 | abalak
# Processing Record 47 of Set 15 | lorengau
# Processing Record 48 of Set 15 | petatlan
# Processing Record 49 of Set 15 | arkhangelsk
# Processing Record 50 of Set 15 | genhe
# Processing Record 1 of Set 16 | charagua
# Processing Record 2 of Set 16 | carnarvon
# Processing Record 3 of Set 16 | charlottesville
# Processing Record 4 of Set 16 | bowen
# Processing Record 5 of Set 16 | bongandanga
# Processing Record 6 of Set 16 | novobirilyussy
# Processing Record 7 of Set 16 | saint-augustin
# Processing Record 8 of Set 16 | chuy
# Processing Record 9 of Set 16 | chama
# Processing Record 10 of Set 16 | vavuniya
# Processing Record 11 of Set 16 | maceio
# Processing Record 12 of Set 16 | middlebury
# Processing Record 13 of Set 16 | pacific grove
# Processing Record 14 of Set 16 | jabiru
# City not found. Skipping...
# Processing Record 15 of Set 16 | portales
# Processing Record 16 of Set 16 | yongan
# Processing Record 17 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 16 | saldanha
# Processing Record 19 of Set 16 | rio bueno
# Processing Record 20 of Set 16 | sitka
# Processing Record 21 of Set 16 | alberton
# Processing Record 22 of Set 16 | alofi
# Processing Record 23 of Set 16 | reidsville
# Processing Record 24 of Set 16 | tuktoyaktuk
# Processing Record 25 of Set 16 | aksarka
# Processing Record 26 of Set 16 | kieta
# Processing Record 27 of Set 16 | filingue
# Processing Record 28 of Set 16 | hasaki
# Processing Record 29 of Set 16 | qasigiannguit
# Processing Record 30 of Set 16 | antofagasta
# Processing Record 31 of Set 16 | pangpang
# Processing Record 32 of Set 16 | ribeira grande
# Processing Record 33 of Set 16 | mahebourg
# Processing Record 34 of Set 16 | bredasdorp
# Processing Record 35 of Set 16 | dwarka
# Processing Record 36 of Set 16 | venado tuerto
# Processing Record 37 of Set 16 | laukaa
# Processing Record 38 of Set 16 | tupik
# Processing Record 39 of Set 16 | port elizabeth
# Processing Record 40 of Set 16 | husavik
# Processing Record 41 of Set 16 | oktyabrskoye
# Processing Record 42 of Set 16 | cabedelo
# Processing Record 43 of Set 16 | giyani
# Processing Record 44 of Set 16 | zhigansk
# Processing Record 45 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 16 | narsaq
# Processing Record 47 of Set 16 | boguchany
# Processing Record 48 of Set 16 | airai
# Processing Record 49 of Set 16 | camacha
# Processing Record 50 of Set 16 | gao
# Processing Record 1 of Set 17 | grindavik
# Processing Record 2 of Set 17 | yenagoa
# Processing Record 3 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 17 | senanga
# Processing Record 5 of Set 17 | mitu
# Processing Record 6 of Set 17 | tessalit
# Processing Record 7 of Set 17 | goundi
# Processing Record 8 of Set 17 | victor harbor
# Processing Record 9 of Set 17 | east london
# Processing Record 10 of Set 17 | flinders
# Processing Record 11 of Set 17 | pisco
# Processing Record 12 of Set 17 | komsomolskiy
# Processing Record 13 of Set 17 | barcelos
# Processing Record 14 of Set 17 | tumpat
# Processing Record 15 of Set 17 | sicamous
# Processing Record 16 of Set 17 | manono
# Processing Record 17 of Set 17 | barentu
# Processing Record 18 of Set 17 | garca
# Processing Record 19 of Set 17 | nagapattinam
# Processing Record 20 of Set 17 | carmen
# Processing Record 21 of Set 17 | nantucket
# Processing Record 22 of Set 17 | mitsamiouli
# Processing Record 23 of Set 17 | lebu
# Processing Record 24 of Set 17 | bam
# Processing Record 25 of Set 17 | saint anthony
# Processing Record 26 of Set 17 | loa janan
# Processing Record 27 of Set 17 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 17 | harnosand
# Processing Record 29 of Set 17 | bethel
# Processing Record 30 of Set 17 | borda da mata
# Processing Record 31 of Set 17 | reyes
# Processing Record 32 of Set 17 | nowa sol
# Processing Record 33 of Set 17 | santander
# Processing Record 34 of Set 17 | bahia de caraquez
# Processing Record 35 of Set 17 | talaya
# Processing Record 36 of Set 17 | kharp
# Processing Record 37 of Set 17 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 17 | port victoria
# Processing Record 39 of Set 17 | pokhara
# Processing Record 40 of Set 17 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 17 | wajima
# Processing Record 42 of Set 17 | angoche
# Processing Record 43 of Set 17 | beihai
# Processing Record 44 of Set 17 | kasongo-lunda
# Processing Record 45 of Set 17 | gigante
# Processing Record 46 of Set 17 | paita
# Processing Record 47 of Set 17 | aykhal
# Processing Record 48 of Set 17 | salinas
# Processing Record 49 of Set 17 | cherskiy
# Processing Record 50 of Set 17 | waingapu
# Processing Record 1 of Set 18 | novyy urengoy
# Processing Record 2 of Set 18 | besikduzu
# Processing Record 3 of Set 18 | souillac
# Processing Record 4 of Set 18 | krasnoselkup
# Processing Record 5 of Set 18 | lazaro cardenas
# Processing Record 6 of Set 18 | nyakahanga
# Processing Record 7 of Set 18 | svetlogorsk
# Processing Record 8 of Set 18 | codrington
# Processing Record 9 of Set 18 | sola
# Processing Record 10 of Set 18 | capitan bado
# Processing Record 11 of Set 18 | kafue
# Processing Record 12 of Set 18 | keti bandar
# Processing Record 13 of Set 18 | roald
# Processing Record 14 of Set 18 | axim
# Processing Record 15 of Set 18 | serov
# Processing Record 16 of Set 18 | port hedland
# Processing Record 17 of Set 18 | chernaya kholunitsa
# Processing Record 18 of Set 18 | tokur
# Processing Record 19 of Set 18 | worland
# Processing Record 20 of Set 18 | pringsewu
# Processing Record 21 of Set 18 | plettenberg bay
# Processing Record 22 of Set 18 | yulara
# Processing Record 23 of Set 18 | katherine
# Processing Record 24 of Set 18 | lieksa
# Processing Record 25 of Set 18 | berlevag
# Processing Record 26 of Set 18 | mansa
# Processing Record 27 of Set 18 | esperance
# Processing Record 28 of Set 18 | kenai
# Processing Record 29 of Set 18 | bolanos de calatrava
# Processing Record 30 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 18 | grong
# Processing Record 32 of Set 18 | mackay
# Processing Record 33 of Set 18 | sarangani
# Processing Record 34 of Set 18 | bambous virieux
# Processing Record 35 of Set 18 | alugan
# Processing Record 36 of Set 18 | banmo
# City not found. Skipping...
# Processing Record 37 of Set 18 | steinbach
# Processing Record 38 of Set 18 | viransehir
# Processing Record 39 of Set 18 | lata
# Processing Record 40 of Set 18 | shimoda
# Processing Record 41 of Set 18 | iqaluit
# Processing Record 42 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 18 | nelson bay
# Processing Record 44 of Set 18 | thinadhoo
# Processing Record 45 of Set 18 | nanning
# Processing Record 46 of Set 18 | fairbanks
# Processing Record 47 of Set 18 | carora
# Processing Record 48 of Set 18 | watertown
# Processing Record 49 of Set 18 | gangotri
# City not found. Skipping...
# Processing Record 50 of Set 18 | aripuana
# Processing Record 1 of Set 19 | pokanayevka
# City not found. Skipping...
# Processing Record 2 of Set 19 | kiruna
# Processing Record 3 of Set 19 | les cayes
# Processing Record 4 of Set 19 | nome
# Processing Record 5 of Set 19 | shuya
# Processing Record 6 of Set 19 | port blair
# Processing Record 7 of Set 19 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 19 | grand gaube
# Processing Record 9 of Set 19 | berkak
# Processing Record 10 of Set 19 | broome
# Processing Record 11 of Set 19 | golubitskaya
# Processing Record 12 of Set 19 | mocuba
# Processing Record 13 of Set 19 | qovlar
# Processing Record 14 of Set 19 | sataua
# City not found. Skipping...
# Processing Record 15 of Set 19 | mayachnyy
# Processing Record 16 of Set 19 | paamiut
# Processing Record 17 of Set 19 | lodja
# Processing Record 18 of Set 19 | cheyenne
# Processing Record 19 of Set 19 | talnakh
# Processing Record 20 of Set 19 | adrar
# Processing Record 21 of Set 19 | ginda
# Processing Record 22 of Set 19 | plasencia
# Processing Record 23 of Set 19 | joacaba
# Processing Record 24 of Set 19 | luderitz
# Processing Record 25 of Set 19 | ban nahin
# Processing Record 26 of Set 19 | isiolo
# Processing Record 27 of Set 19 | naze
# Processing Record 28 of Set 19 | bonavista
# Processing Record 29 of Set 19 | vorotynets
# Processing Record 30 of Set 19 | rondonopolis
# Processing Record 31 of Set 19 | robore
# Processing Record 32 of Set 19 | provideniya
# Processing Record 33 of Set 19 | fort frances
# Processing Record 34 of Set 19 | bor
# Processing Record 35 of Set 19 | lagoa
# Processing Record 36 of Set 19 | shijak
# Processing Record 37 of Set 19 | qostanay
# Processing Record 38 of Set 19 | damghan
# Processing Record 39 of Set 19 | tuljapur
# Processing Record 40 of Set 19 | north platte
# Processing Record 41 of Set 19 | tazmalt
# Processing Record 42 of Set 19 | kawalu
# Processing Record 43 of Set 19 | moose factory
# Processing Record 44 of Set 19 | ambon
# Processing Record 45 of Set 19 | cairns
# Processing Record 46 of Set 19 | ewa beach
# Processing Record 47 of Set 19 | ancud
# Processing Record 48 of Set 19 | la palma
# Processing Record 49 of Set 19 | virginia beach
# Processing Record 50 of Set 19 | ponta do sol
# Processing Record 1 of Set 20 | shellbrook
# Processing Record 2 of Set 20 | gualaquiza
# Processing Record 3 of Set 20 | geraldton
# Processing Record 4 of Set 20 | tera
# Processing Record 5 of Set 20 | eyl
# Processing Record 6 of Set 20 | coahuayana
# Processing Record 7 of Set 20 | crestview
# Processing Record 8 of Set 20 | vao
# Processing Record 9 of Set 20 | mount gambier
# Processing Record 10 of Set 20 | okhotsk
# Processing Record 11 of Set 20 | klaksvik
# Processing Record 12 of Set 20 | andernach
# Processing Record 13 of Set 20 | matameye
# City not found. Skipping...
# Processing Record 14 of Set 20 | rayevskiy
# Processing Record 15 of Set 20 | mao
# Processing Record 16 of Set 20 | grants pass
# Processing Record 17 of Set 20 | half moon bay
# Processing Record 18 of Set 20 | bridgetown
# Processing Record 19 of Set 20 | nicoya
# Processing Record 20 of Set 20 | pimenteiras
# Processing Record 21 of Set 20 | cody
# Processing Record 22 of Set 20 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 20 | chicama
# Processing Record 24 of Set 20 | moshkovo
# Processing Record 25 of Set 20 | mishelevka
# Processing Record 26 of Set 20 | kichera
# Processing Record 27 of Set 20 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 20 | buarcos
# Processing Record 29 of Set 20 | ixtapa
# Processing Record 30 of Set 20 | te anau
# Processing Record 31 of Set 20 | pleasanton
# Processing Record 32 of Set 20 | kahului
# Processing Record 33 of Set 20 | boddam
# Processing Record 34 of Set 20 | bundaberg
# Processing Record 35 of Set 20 | omboue
# Processing Record 36 of Set 20 | edmundston
# Processing Record 37 of Set 20 | nova odesa
# Processing Record 38 of Set 20 | tres arroyos
# Processing Record 39 of Set 20 | charlestown
# Processing Record 40 of Set 20 | padang
# Processing Record 41 of Set 20 | san lorenzo de el escorial
# Processing Record 42 of Set 20 | ponta delgada
# Processing Record 43 of Set 20 | burica
# City not found. Skipping...
# Processing Record 44 of Set 20 | piney green
# Processing Record 45 of Set 20 | ararangua
# Processing Record 46 of Set 20 | nador
# Processing Record 47 of Set 20 | siocon
# Processing Record 48 of Set 20 | buraydah
# Processing Record 49 of Set 20 | ketchikan
# Processing Record 50 of Set 20 | arlit
# Processing Record 1 of Set 21 | petrozavodsk
# Processing Record 2 of Set 21 | alta floresta
# Processing Record 3 of Set 21 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 21 | hualmay
# Processing Record 5 of Set 21 | san jeronimo
# Processing Record 6 of Set 21 | rabo de peixe
# Processing Record 7 of Set 21 | trapani
# Processing Record 8 of Set 21 | rossland
# Processing Record 9 of Set 21 | ormara
# Processing Record 10 of Set 21 | mount isa
# Processing Record 11 of Set 21 | saint george
# Processing Record 12 of Set 21 | comodoro rivadavia
# Processing Record 13 of Set 21 | goundam
# Processing Record 14 of Set 21 | tura
# Processing Record 15 of Set 21 | alma
# Processing Record 16 of Set 21 | dunedin
# Processing Record 17 of Set 21 | sept-iles
# Processing Record 18 of Set 21 | vila velha
# Processing Record 19 of Set 21 | mendi
# Processing Record 20 of Set 21 | katobu
# Processing Record 21 of Set 21 | manta
# Processing Record 22 of Set 21 | imbituba
# Processing Record 23 of Set 21 | shache
# Processing Record 24 of Set 21 | itaueira
# Processing Record 25 of Set 21 | bocas del toro
# Processing Record 26 of Set 21 | innisfail
# Processing Record 27 of Set 21 | stromness
# Processing Record 28 of Set 21 | bom jardim
# Processing Record 29 of Set 21 | helsinki
# Processing Record 30 of Set 21 | hofn
# Processing Record 31 of Set 21 | jamame
# Processing Record 32 of Set 21 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 21 | cidreira
# Processing Record 34 of Set 21 | bara
# Processing Record 35 of Set 21 | llanes
# Processing Record 36 of Set 21 | dzaoudzi
# Processing Record 37 of Set 21 | dauphin
# Processing Record 38 of Set 21 | kyra
# Processing Record 39 of Set 21 | susanville
# Processing Record 40 of Set 21 | straumen
# Processing Record 41 of Set 21 | pueblo
# Processing Record 42 of Set 21 | milkovo
# Processing Record 43 of Set 21 | graham
# Processing Record 44 of Set 21 | constitucion
# Processing Record 45 of Set 21 | nobeoka
# Processing Record 46 of Set 21 | binabalian
# Processing Record 47 of Set 21 | moussoro
# Processing Record 48 of Set 21 | harer
# Processing Record 49 of Set 21 | mendoza
# Processing Record 50 of Set 21 | singaraja
# Processing Record 1 of Set 22 | matadi
# Processing Record 2 of Set 22 | brus laguna
# Processing Record 3 of Set 22 | sao filipe
# Processing Record 4 of Set 22 | biak
# Processing Record 5 of Set 22 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 22 | nakamura
# Processing Record 7 of Set 22 | ngunguru
# Processing Record 8 of Set 22 | atikokan
# Processing Record 9 of Set 22 | coolum beach
# Processing Record 10 of Set 22 | cape coast
# Processing Record 11 of Set 22 | warren
# Processing Record 12 of Set 22 | havre-saint-pierre
# Processing Record 13 of Set 22 | port augusta
# Processing Record 14 of Set 22 | yukamenskoye
# Processing Record 15 of Set 22 | saint-francois
# Processing Record 16 of Set 22 | nishihara
# Processing Record 17 of Set 22 | jizan
# Processing Record 18 of Set 22 | kletnya
# Processing Record 19 of Set 22 | tawnat
# City not found. Skipping...
# Processing Record 20 of Set 22 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 22 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 22 | gat
# Processing Record 23 of Set 22 | yurimaguas
# Processing Record 24 of Set 22 | hakvik
# City not found. Skipping...
# Processing Record 25 of Set 22 | xaxim
# Processing Record 26 of Set 22 | san quintin
# Processing Record 27 of Set 22 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 22 | portland
# Processing Record 29 of Set 22 | kuytun
# Processing Record 30 of Set 22 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 22 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 22 | ayan
# Processing Record 33 of Set 22 | nouadhibou
# Processing Record 34 of Set 22 | numan
# Processing Record 35 of Set 22 | ugra
# Processing Record 36 of Set 22 | tyrma
# Processing Record 37 of Set 22 | romny
# Processing Record 38 of Set 22 | tocantins
# Processing Record 39 of Set 22 | tautira
# Processing Record 40 of Set 22 | adre
# Processing Record 41 of Set 22 | campoverde
# Processing Record 42 of Set 22 | oriximina
# Processing Record 43 of Set 22 | desaguadero
# Processing Record 44 of Set 22 | srednekolymsk
# Processing Record 45 of Set 22 | phan thiet
# Processing Record 46 of Set 22 | chuguyevka
# Processing Record 47 of Set 22 | bathsheba
# Processing Record 48 of Set 22 | pontianak
# Processing Record 49 of Set 22 | bilibino
# Processing Record 50 of Set 22 | ahipara
# Processing Record 1 of Set 23 | casas grandes
# Processing Record 2 of Set 23 | moree
# Processing Record 3 of Set 23 | shaunavon
# Processing Record 4 of Set 23 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 23 | daru
# Processing Record 6 of Set 23 | revda
# Processing Record 7 of Set 23 | hami
# Processing Record 8 of Set 23 | mancio lima
# Processing Record 9 of Set 23 | ushtobe
# Processing Record 10 of Set 23 | vizinga
# Processing Record 11 of Set 23 | maghama
# City not found. Skipping...
# Processing Record 12 of Set 23 | port lincoln
# Processing Record 13 of Set 23 | la presa
# Processing Record 14 of Set 23 | dingle
# Processing Record 15 of Set 23 | labuhan
# Processing Record 16 of Set 23 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 23 | mangrol
# Processing Record 18 of Set 23 | ulenje
# Processing Record 19 of Set 23 | waipawa
# Processing Record 20 of Set 23 | muisne
# Processing Record 21 of Set 23 | saint-georges
# Processing Record 22 of Set 23 | ranong
# Processing Record 23 of Set 23 | westerland
# Processing Record 24 of Set 23 | port macquarie
# Processing Record 25 of Set 23 | chara
# Processing Record 26 of Set 23 | aquiraz
# Processing Record 27 of Set 23 | ambulu
# Processing Record 28 of Set 23 | weiser
# Processing Record 29 of Set 23 | chabua
# Processing Record 30 of Set 23 | chernyshevskiy
# Processing Record 31 of Set 23 | krasnoarmeysk
# Processing Record 32 of Set 23 | pangnirtung
# Processing Record 33 of Set 23 | lubao
# Processing Record 34 of Set 23 | edgewater
# Processing Record 35 of Set 23 | mocambique
# City not found. Skipping...
# Processing Record 36 of Set 23 | cayenne
# Processing Record 37 of Set 23 | marawi
# Processing Record 38 of Set 23 | noumea
# Processing Record 39 of Set 23 | huarmey
# Processing Record 40 of Set 23 | henties bay
# Processing Record 41 of Set 23 | kantunilkin
# Processing Record 42 of Set 23 | itarema
# Processing Record 43 of Set 23 | laguna
# Processing Record 44 of Set 23 | hargeysa
# Processing Record 45 of Set 23 | isla vista
# Processing Record 46 of Set 23 | hirara
# Processing Record 47 of Set 23 | disna
# Processing Record 48 of Set 23 | coihaique
# Processing Record 49 of Set 23 | tawzar
# City not found. Skipping...
# Processing Record 50 of Set 23 | dunbar
# Processing Record 1 of Set 24 | road town
# Processing Record 2 of Set 24 | rio grande
# Processing Record 3 of Set 24 | christchurch
# Processing Record 4 of Set 24 | babanusah
# City not found. Skipping...
# Processing Record 5 of Set 24 | asau
# Processing Record 6 of Set 24 | oktyabrskiy
# Processing Record 7 of Set 24 | jacmel
# Processing Record 8 of Set 24 | talhar
# Processing Record 9 of Set 24 | kota belud
# Processing Record 10 of Set 24 | georgiyevka
# Processing Record 11 of Set 24 | tuatapere
# Processing Record 12 of Set 24 | samarai
# Processing Record 13 of Set 24 | siderno
# Processing Record 14 of Set 24 | joensuu
# Processing Record 15 of Set 24 | lemesos
# City not found. Skipping...
# Processing Record 16 of Set 24 | saint-joseph
# Processing Record 17 of Set 24 | ayni
# Processing Record 18 of Set 24 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 24 | maldonado
# Processing Record 20 of Set 24 | awjilah
# Processing Record 21 of Set 24 | kahramanmaras
# Processing Record 22 of Set 24 | trairi
# Processing Record 23 of Set 24 | launceston
# Processing Record 24 of Set 24 | tukrah
# Processing Record 25 of Set 24 | morant bay
# Processing Record 26 of Set 24 | berbera
# Processing Record 27 of Set 24 | kapit
# Processing Record 28 of Set 24 | pont-rouge
# Processing Record 29 of Set 24 | quang ngai
# Processing Record 30 of Set 24 | pochinki
# Processing Record 31 of Set 24 | lincoln
# Processing Record 32 of Set 24 | sambava
# Processing Record 33 of Set 24 | sabang
# Processing Record 34 of Set 24 | gursu
# Processing Record 35 of Set 24 | durban
# Processing Record 36 of Set 24 | santa isabel
# Processing Record 37 of Set 24 | khatanga
# Processing Record 38 of Set 24 | ulaanbaatar
# Processing Record 39 of Set 24 | pemangkat
# Processing Record 40 of Set 24 | bintulu
# Processing Record 41 of Set 24 | westport
# Processing Record 42 of Set 24 | high level
# Processing Record 43 of Set 24 | vicuna
# Processing Record 44 of Set 24 | fianga
# City not found. Skipping...
# Processing Record 45 of Set 24 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 24 | vacaria
# Processing Record 47 of Set 24 | strelka
# Processing Record 48 of Set 24 | tual
# Processing Record 49 of Set 24 | tulnici
# Processing Record 50 of Set 24 | guerrero negro
# Processing Record 1 of Set 25 | belmonte
# Processing Record 2 of Set 25 | rafraf
# Processing Record 3 of Set 25 | hit
# Processing Record 4 of Set 25 | ozark
# Processing Record 5 of Set 25 | olafsvik
# Processing Record 6 of Set 25 | tubmanburg
# Processing Record 7 of Set 25 | jining
# Processing Record 8 of Set 25 | pitsunda
# Processing Record 9 of Set 25 | salcioara
# Processing Record 10 of Set 25 | la ronge
# Processing Record 11 of Set 25 | rocha
# Processing Record 12 of Set 25 | kamenka
# Processing Record 13 of Set 25 | poum
# Processing Record 14 of Set 25 | divnomorskoye
# Processing Record 15 of Set 25 | terra santa
# Processing Record 16 of Set 25 | dillon
# Processing Record 17 of Set 25 | nago
# Processing Record 18 of Set 25 | verkhoyansk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Fort-Shevchenko  44.5086   50.2630     48.24        40           0
# 1         Nanortalik  60.1432  -45.2371     37.13        63           0
# 2          Ilulissat  69.2167  -51.1000     24.82        39          53
# 3       Richards Bay -28.7830   32.0377     66.88        91          62
# 4       Longyearbyen  78.2186   15.6401     19.24        73           0
# ..               ...      ...       ...       ...       ...         ...
# 567    Divnomorskoye  44.5011   38.1353     47.75        80          96
# 568      Terra Santa  -2.1042  -56.4869     78.91        75          99
# 569           Dillon  34.4166  -79.3712     72.36        96         100
# 570             Nago  26.5881  127.9761     86.16        74           7
# 571      Verkhoyansk  67.5447  133.3850     28.18        48         100
#
#      Wind Speed Country                 Date
# 0          9.31      KZ  2021-10-09 02:24:42
# 1          6.64      GL  2021-10-09 02:27:47
# 2         13.80      GL  2021-10-09 02:29:34
# 3          8.39      ZA  2021-10-09 02:29:35
# 4         10.36      SJ  2021-10-09 02:29:27
# ..          ...     ...                  ...
# 567        9.71      RU  2021-10-09 02:34:15
# 568        2.95      BR  2021-10-09 02:34:16
# 569        3.56      US  2021-10-09 02:34:16
# 570       15.50      JP  2021-10-09 02:34:17
# 571        6.69      RU  2021-10-09 02:34:17
#
# [572 rows x 9 columns]

# %%
new_columnn_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_columnn_order]
city_data_df
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0    Fort-Shevchenko      KZ  2021-10-09 02:24:42  44.5086   50.2630
# 1         Nanortalik      GL  2021-10-09 02:27:47  60.1432  -45.2371
# 2          Ilulissat      GL  2021-10-09 02:29:34  69.2167  -51.1000
# 3       Richards Bay      ZA  2021-10-09 02:29:35 -28.7830   32.0377
# 4       Longyearbyen      SJ  2021-10-09 02:29:27  78.2186   15.6401
# ..               ...     ...                  ...      ...       ...
# 567    Divnomorskoye      RU  2021-10-09 02:34:15  44.5011   38.1353
# 568      Terra Santa      BR  2021-10-09 02:34:16  -2.1042  -56.4869
# 569           Dillon      US  2021-10-09 02:34:16  34.4166  -79.3712
# 570             Nago      JP  2021-10-09 02:34:17  26.5881  127.9761
# 571      Verkhoyansk      RU  2021-10-09 02:34:17  67.5447  133.3850
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       48.24        40           0        9.31
# 1       37.13        63           0        6.64
# 2       24.82        39          53       13.80
# 3       66.88        91          62        8.39
# 4       19.24        73           0       10.36
# ..        ...       ...         ...         ...
# 567     47.75        80          96        9.71
# 568     78.91        75          99        2.95
# 569     72.36        96         100        3.56
# 570     86.16        74           7       15.50
# 571     28.18        48         100        6.69
#
# [572 rows x 9 columns]

# %%
# Create the output file (CSV)
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
           max_temps,
           edgecolor='black', linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Build the scatter plots for latitude vs. humanity.
plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")
# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity ")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")
# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
           wind_speed,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
