# %%
# Generate 2,000 random latitudes and longitudes
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import requests
import config
from datetime import datetime

# %%
from config import API_weather

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
URL = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_weather
print(URL)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d5f365fbea14123356d30c64071da89

# %%
# Get the nearest city using citypy
from citipy import citipy

# %%
cities = []

# %%
# Get the nearest city using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 776

# %%
# Loop through all the cities in the list.
for i in range(len(cities)):
    
    # Group the cities in sets of 50
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = URL + "&q=" + cities[i]

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = URL + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | wilmington
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | uruguaiana
# Processing Record 6 of Set 1 | borogontsy
# Processing Record 7 of Set 1 | mancio lima
# Processing Record 8 of Set 1 | grindavik
# Processing Record 9 of Set 1 | brisbane
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | sao filipe
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | banda aceh
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | nishihara
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | geraldton
# Processing Record 20 of Set 1 | imbituba
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | katsuura
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | cherskiy
# Processing Record 26 of Set 1 | dryden
# Processing Record 27 of Set 1 | ust-tsilma
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | haines junction
# Processing Record 31 of Set 1 | pevek
# Processing Record 32 of Set 1 | hambantota
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | provideniya
# Processing Record 35 of Set 1 | port hedland
# Processing Record 36 of Set 1 | hongjiang
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | ternate
# Processing Record 39 of Set 1 | kangaatsiaq
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | charters towers
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | karasjok
# Processing Record 44 of Set 1 | abha
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | port macquarie
# Processing Record 48 of Set 1 | plettenberg bay
# Processing Record 49 of Set 1 | thinadhoo
# Processing Record 50 of Set 1 | narsaq
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | brookings
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | turukhansk
# Processing Record 6 of Set 2 | ilulissat
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 2 | znamensk
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | auch
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | dikson
# Processing Record 15 of Set 2 | carutapera
# Processing Record 16 of Set 2 | dudinka
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | burica
# City not found. Skipping...
# Processing Record 19 of Set 2 | sal rei
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | nanortalik
# Processing Record 23 of Set 2 | half moon bay
# Processing Record 24 of Set 2 | luganville
# Processing Record 25 of Set 2 | adeje
# Processing Record 26 of Set 2 | visby
# Processing Record 27 of Set 2 | acarau
# Processing Record 28 of Set 2 | olafsvik
# Processing Record 29 of Set 2 | asau
# Processing Record 30 of Set 2 | sistranda
# Processing Record 31 of Set 2 | mineral wells
# Processing Record 32 of Set 2 | kruisfontein
# Processing Record 33 of Set 2 | novochernorechenskiy
# Processing Record 34 of Set 2 | feira de santana
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | gornyy
# Processing Record 37 of Set 2 | otradnoye
# Processing Record 38 of Set 2 | kapaa
# Processing Record 39 of Set 2 | dunedin
# Processing Record 40 of Set 2 | yulara
# Processing Record 41 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 2 | nizhniy tsasuchey
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | mehamn
# Processing Record 46 of Set 2 | rawson
# Processing Record 47 of Set 2 | tasiilaq
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | kologriv
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | cruden bay
# City not found. Skipping...
# Processing Record 2 of Set 3 | yarim
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | abu dhabi
# Processing Record 5 of Set 3 | bakaly
# Processing Record 6 of Set 3 | samarai
# Processing Record 7 of Set 3 | vikindu
# Processing Record 8 of Set 3 | bodden town
# Processing Record 9 of Set 3 | axim
# Processing Record 10 of Set 3 | bredasdorp
# Processing Record 11 of Set 3 | airai
# Processing Record 12 of Set 3 | onega
# Processing Record 13 of Set 3 | penzance
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | eureka
# Processing Record 16 of Set 3 | trincomalee
# Processing Record 17 of Set 3 | koboldo
# City not found. Skipping...
# Processing Record 18 of Set 3 | stromness
# Processing Record 19 of Set 3 | luena
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | hasaki
# Processing Record 22 of Set 3 | bethanien
# Processing Record 23 of Set 3 | san jose
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | alta floresta
# Processing Record 27 of Set 3 | shirokiy
# Processing Record 28 of Set 3 | te anau
# Processing Record 29 of Set 3 | tabuk
# Processing Record 30 of Set 3 | berlevag
# Processing Record 31 of Set 3 | nizwa
# Processing Record 32 of Set 3 | chapais
# Processing Record 33 of Set 3 | andapa
# Processing Record 34 of Set 3 | grand gaube
# Processing Record 35 of Set 3 | srednekolymsk
# Processing Record 36 of Set 3 | tiarei
# Processing Record 37 of Set 3 | moron
# Processing Record 38 of Set 3 | longyearbyen
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 42 of Set 3 | san quintin
# Processing Record 43 of Set 3 | cap malheureux
# Processing Record 44 of Set 3 | lompoc
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | torbay
# Processing Record 47 of Set 3 | tucuman
# Processing Record 48 of Set 3 | ambikapur
# Processing Record 49 of Set 3 | saint george
# Processing Record 50 of Set 3 | angol
# Processing Record 1 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 4 | temir
# Processing Record 3 of Set 4 | saldanha
# Processing Record 4 of Set 4 | kadoma
# Processing Record 5 of Set 4 | tazovskiy
# Processing Record 6 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 4 | saryg-sep
# Processing Record 8 of Set 4 | yerbogachen
# Processing Record 9 of Set 4 | marystown
# Processing Record 10 of Set 4 | oranjemund
# Processing Record 11 of Set 4 | vyazemskiy
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | sinzheim
# Processing Record 14 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 4 | dawlatabad
# Processing Record 16 of Set 4 | vredendal
# Processing Record 17 of Set 4 | dabat
# Processing Record 18 of Set 4 | yerkoy
# Processing Record 19 of Set 4 | touros
# Processing Record 20 of Set 4 | bilibino
# Processing Record 21 of Set 4 | papetoai
# Processing Record 22 of Set 4 | mount isa
# Processing Record 23 of Set 4 | perehonivka
# Processing Record 24 of Set 4 | mahebourg
# Processing Record 25 of Set 4 | quatre cocos
# Processing Record 26 of Set 4 | clyde river
# Processing Record 27 of Set 4 | ust-ishim
# Processing Record 28 of Set 4 | cilegon
# Processing Record 29 of Set 4 | sulangan
# Processing Record 30 of Set 4 | deputatskiy
# Processing Record 31 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 4 | bilma
# Processing Record 33 of Set 4 | namatanai
# Processing Record 34 of Set 4 | utiel
# Processing Record 35 of Set 4 | umm lajj
# Processing Record 36 of Set 4 | eufaula
# Processing Record 37 of Set 4 | aljezur
# Processing Record 38 of Set 4 | glyadyanskoye
# Processing Record 39 of Set 4 | santa isabel
# Processing Record 40 of Set 4 | warri
# Processing Record 41 of Set 4 | tunxi
# City not found. Skipping...
# Processing Record 42 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 4 | lewisporte
# Processing Record 44 of Set 4 | mount gambier
# Processing Record 45 of Set 4 | victoria
# Processing Record 46 of Set 4 | svetlyy
# Processing Record 47 of Set 4 | rundu
# Processing Record 48 of Set 4 | matara
# Processing Record 49 of Set 4 | sabang
# Processing Record 50 of Set 4 | klaksvik
# Processing Record 1 of Set 5 | talnakh
# Processing Record 2 of Set 5 | ixtapa
# Processing Record 3 of Set 5 | bamberg
# Processing Record 4 of Set 5 | aswan
# Processing Record 5 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 5 | kahului
# Processing Record 7 of Set 5 | vila velha
# Processing Record 8 of Set 5 | fez
# Processing Record 9 of Set 5 | kayes
# Processing Record 10 of Set 5 | mahibadhoo
# Processing Record 11 of Set 5 | kavaratti
# Processing Record 12 of Set 5 | nosy varika
# Processing Record 13 of Set 5 | khatanga
# Processing Record 14 of Set 5 | taseyevo
# Processing Record 15 of Set 5 | salekhard
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | duku
# Processing Record 18 of Set 5 | pangnirtung
# Processing Record 19 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 5 | traverse city
# Processing Record 21 of Set 5 | najran
# Processing Record 22 of Set 5 | faanui
# Processing Record 23 of Set 5 | kisangani
# Processing Record 24 of Set 5 | aykhal
# Processing Record 25 of Set 5 | kushima
# Processing Record 26 of Set 5 | san remo
# Processing Record 27 of Set 5 | mustasaari
# Processing Record 28 of Set 5 | santa maria
# Processing Record 29 of Set 5 | bandarbeyla
# Processing Record 30 of Set 5 | carnarvon
# Processing Record 31 of Set 5 | krasnoznamensk
# Processing Record 32 of Set 5 | mushie
# Processing Record 33 of Set 5 | cayenne
# Processing Record 34 of Set 5 | ishigaki
# Processing Record 35 of Set 5 | turki
# Processing Record 36 of Set 5 | bosaso
# Processing Record 37 of Set 5 | prince rupert
# Processing Record 38 of Set 5 | qaqortoq
# Processing Record 39 of Set 5 | auki
# Processing Record 40 of Set 5 | hami
# Processing Record 41 of Set 5 | langxiang
# Processing Record 42 of Set 5 | manicore
# Processing Record 43 of Set 5 | marovoay
# Processing Record 44 of Set 5 | tiznit
# Processing Record 45 of Set 5 | nampa
# Processing Record 46 of Set 5 | karratha
# Processing Record 47 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 5 | garissa
# Processing Record 49 of Set 5 | puerto ayacucho
# Processing Record 50 of Set 5 | ust-nera
# Processing Record 1 of Set 6 | muros
# Processing Record 2 of Set 6 | lapua
# Processing Record 3 of Set 6 | kloulklubed
# Processing Record 4 of Set 6 | campestre
# Processing Record 5 of Set 6 | hirara
# Processing Record 6 of Set 6 | nortelandia
# Processing Record 7 of Set 6 | coquimbo
# Processing Record 8 of Set 6 | milingimbi
# City not found. Skipping...
# Processing Record 9 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 6 | salinas
# Processing Record 11 of Set 6 | urumqi
# Processing Record 12 of Set 6 | ahipara
# Processing Record 13 of Set 6 | sulzbach-rosenberg
# Processing Record 14 of Set 6 | bitung
# Processing Record 15 of Set 6 | cove
# Processing Record 16 of Set 6 | sydney mines
# Processing Record 17 of Set 6 | cozumel
# Processing Record 18 of Set 6 | ossora
# Processing Record 19 of Set 6 | koumac
# Processing Record 20 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 6 | sioux lookout
# Processing Record 22 of Set 6 | mamlyutka
# Processing Record 23 of Set 6 | iqaluit
# Processing Record 24 of Set 6 | praia da vitoria
# Processing Record 25 of Set 6 | ekhabi
# Processing Record 26 of Set 6 | norman wells
# Processing Record 27 of Set 6 | salta
# Processing Record 28 of Set 6 | uch
# Processing Record 29 of Set 6 | jalpaiguri
# Processing Record 30 of Set 6 | baglan
# Processing Record 31 of Set 6 | codrington
# Processing Record 32 of Set 6 | anqiu
# Processing Record 33 of Set 6 | sao joao da barra
# Processing Record 34 of Set 6 | alpatovo
# Processing Record 35 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 6 | beloha
# Processing Record 37 of Set 6 | batagay
# Processing Record 38 of Set 6 | aguas formosas
# Processing Record 39 of Set 6 | port hueneme
# Processing Record 40 of Set 6 | bulungu
# Processing Record 41 of Set 6 | opuwo
# Processing Record 42 of Set 6 | ambagarh chauki
# Processing Record 43 of Set 6 | sinnamary
# Processing Record 44 of Set 6 | alora
# Processing Record 45 of Set 6 | novokizhinginsk
# Processing Record 46 of Set 6 | samur
# Processing Record 47 of Set 6 | fare
# Processing Record 48 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 49 of Set 6 | kurchum
# Processing Record 50 of Set 6 | raga
# Processing Record 1 of Set 7 | college
# Processing Record 2 of Set 7 | fortuna
# Processing Record 3 of Set 7 | avera
# Processing Record 4 of Set 7 | flinders
# Processing Record 5 of Set 7 | fomboni
# Processing Record 6 of Set 7 | alofi
# Processing Record 7 of Set 7 | cabo san lucas
# Processing Record 8 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 7 | tayu
# Processing Record 10 of Set 7 | seymchan
# Processing Record 11 of Set 7 | dakar
# Processing Record 12 of Set 7 | ribeira grande
# Processing Record 13 of Set 7 | maceio
# Processing Record 14 of Set 7 | lorengau
# Processing Record 15 of Set 7 | praya
# Processing Record 16 of Set 7 | saint-philippe
# Processing Record 17 of Set 7 | goderich
# Processing Record 18 of Set 7 | tarko-sale
# Processing Record 19 of Set 7 | kattivakkam
# Processing Record 20 of Set 7 | buchanan
# Processing Record 21 of Set 7 | mucuri
# Processing Record 22 of Set 7 | nemuro
# Processing Record 23 of Set 7 | kota tinggi
# Processing Record 24 of Set 7 | bethel
# Processing Record 25 of Set 7 | lagoa
# Processing Record 26 of Set 7 | nikolskoye
# Processing Record 27 of Set 7 | gravdal
# Processing Record 28 of Set 7 | chandbali
# Processing Record 29 of Set 7 | port hawkesbury
# Processing Record 30 of Set 7 | takoradi
# Processing Record 31 of Set 7 | mitsamiouli
# Processing Record 32 of Set 7 | san cristobal
# Processing Record 33 of Set 7 | kununurra
# Processing Record 34 of Set 7 | la palma
# Processing Record 35 of Set 7 | puerto escondido
# Processing Record 36 of Set 7 | mattru
# Processing Record 37 of Set 7 | benghazi
# Processing Record 38 of Set 7 | isangel
# Processing Record 39 of Set 7 | krasnoselkup
# Processing Record 40 of Set 7 | ewa beach
# Processing Record 41 of Set 7 | calama
# Processing Record 42 of Set 7 | masunga
# Processing Record 43 of Set 7 | tura
# Processing Record 44 of Set 7 | hamilton
# Processing Record 45 of Set 7 | itoman
# Processing Record 46 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 7 | saskylakh
# Processing Record 48 of Set 7 | kijang
# Processing Record 49 of Set 7 | sumbe
# Processing Record 50 of Set 7 | ede
# Processing Record 1 of Set 8 | sterling
# Processing Record 2 of Set 8 | porto novo
# Processing Record 3 of Set 8 | kodiak
# Processing Record 4 of Set 8 | sao jose da coroa grande
# Processing Record 5 of Set 8 | pierre
# Processing Record 6 of Set 8 | saint anthony
# Processing Record 7 of Set 8 | cockburn town
# Processing Record 8 of Set 8 | manjacaze
# Processing Record 9 of Set 8 | omsukchan
# Processing Record 10 of Set 8 | glendive
# Processing Record 11 of Set 8 | ponta delgada
# Processing Record 12 of Set 8 | mkokotoni
# Processing Record 13 of Set 8 | wolmaranstad
# City not found. Skipping...
# Processing Record 14 of Set 8 | lalmohan
# Processing Record 15 of Set 8 | henties bay
# Processing Record 16 of Set 8 | coihaique
# Processing Record 17 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 19 of Set 8 | jaicos
# Processing Record 20 of Set 8 | tiksi
# Processing Record 21 of Set 8 | ludvika
# Processing Record 22 of Set 8 | marawi
# Processing Record 23 of Set 8 | portland
# Processing Record 24 of Set 8 | yar-sale
# Processing Record 25 of Set 8 | tete
# Processing Record 26 of Set 8 | adrar
# Processing Record 27 of Set 8 | mirnyy
# Processing Record 28 of Set 8 | zatoka
# Processing Record 29 of Set 8 | chernyshevskiy
# Processing Record 30 of Set 8 | ojinaga
# Processing Record 31 of Set 8 | kidal
# Processing Record 32 of Set 8 | esperance
# Processing Record 33 of Set 8 | catuday
# Processing Record 34 of Set 8 | verkhnevilyuysk
# Processing Record 35 of Set 8 | cap-aux-meules
# Processing Record 36 of Set 8 | ngunguru
# Processing Record 37 of Set 8 | ye
# City not found. Skipping...
# Processing Record 38 of Set 8 | aksum
# Processing Record 39 of Set 8 | kunya
# Processing Record 40 of Set 8 | shrirangapattana
# Processing Record 41 of Set 8 | mugur-aksy
# Processing Record 42 of Set 8 | port lincoln
# Processing Record 43 of Set 8 | vao
# Processing Record 44 of Set 8 | raahe
# Processing Record 45 of Set 8 | kenai
# Processing Record 46 of Set 8 | morant bay
# Processing Record 47 of Set 8 | ewo
# Processing Record 48 of Set 8 | kitimat
# Processing Record 49 of Set 8 | mackay
# Processing Record 50 of Set 8 | puerto madryn
# Processing Record 1 of Set 9 | bathsheba
# Processing Record 2 of Set 9 | sorong
# Processing Record 3 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 4 of Set 9 | celestun
# Processing Record 5 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 9 | nome
# Processing Record 7 of Set 9 | lircay
# Processing Record 8 of Set 9 | esterhazy
# Processing Record 9 of Set 9 | ailigandi
# Processing Record 10 of Set 9 | salvador
# Processing Record 11 of Set 9 | doka
# Processing Record 12 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 9 | tabou
# Processing Record 15 of Set 9 | bo rai
# Processing Record 16 of Set 9 | challans
# Processing Record 17 of Set 9 | azanka
# Processing Record 18 of Set 9 | tyukhtet
# Processing Record 19 of Set 9 | chipinge
# Processing Record 20 of Set 9 | pangai
# Processing Record 21 of Set 9 | honningsvag
# Processing Record 22 of Set 9 | maniitsoq
# Processing Record 23 of Set 9 | santa branca
# Processing Record 24 of Set 9 | vilyuysk
# Processing Record 25 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 9 | bontang
# Processing Record 27 of Set 9 | turayf
# Processing Record 28 of Set 9 | mitzic
# Processing Record 29 of Set 9 | faya
# Processing Record 30 of Set 9 | toyooka
# Processing Record 31 of Set 9 | loandjili
# Processing Record 32 of Set 9 | tuatapere
# Processing Record 33 of Set 9 | thompson
# Processing Record 34 of Set 9 | vila franca do campo
# Processing Record 35 of Set 9 | presidencia roque saenz pena
# Processing Record 36 of Set 9 | batagay-alyta
# Processing Record 37 of Set 9 | latung
# Processing Record 38 of Set 9 | bambous virieux
# Processing Record 39 of Set 9 | porto velho
# Processing Record 40 of Set 9 | saint-francois
# Processing Record 41 of Set 9 | valdemarpils
# Processing Record 42 of Set 9 | nouadhibou
# Processing Record 43 of Set 9 | manzhouli
# Processing Record 44 of Set 9 | bam
# Processing Record 45 of Set 9 | ponta do sol
# Processing Record 46 of Set 9 | swift current
# Processing Record 47 of Set 9 | tezu
# Processing Record 48 of Set 9 | paamiut
# Processing Record 49 of Set 9 | lavrentiya
# Processing Record 50 of Set 9 | mogadishu
# Processing Record 1 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 10 | laje
# Processing Record 3 of Set 10 | olinda
# Processing Record 4 of Set 10 | magnolia
# Processing Record 5 of Set 10 | matay
# Processing Record 6 of Set 10 | bonthe
# Processing Record 7 of Set 10 | leningradskiy
# Processing Record 8 of Set 10 | bani
# Processing Record 9 of Set 10 | tchollire
# Processing Record 10 of Set 10 | ostroleka
# Processing Record 11 of Set 10 | ostrovnoy
# Processing Record 12 of Set 10 | boxtel
# Processing Record 13 of Set 10 | cangzhou
# Processing Record 14 of Set 10 | luderitz
# Processing Record 15 of Set 10 | northam
# Processing Record 16 of Set 10 | dalby
# Processing Record 17 of Set 10 | vanimo
# Processing Record 18 of Set 10 | areosa
# Processing Record 19 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 10 | port hardy
# Processing Record 21 of Set 10 | richards bay
# Processing Record 22 of Set 10 | clinton
# Processing Record 23 of Set 10 | guerrero negro
# Processing Record 24 of Set 10 | coreau
# Processing Record 25 of Set 10 | borascu
# Processing Record 26 of Set 10 | akom
# Processing Record 27 of Set 10 | balclutha
# Processing Record 28 of Set 10 | cuamba
# Processing Record 29 of Set 10 | wakefield
# Processing Record 30 of Set 10 | beyla
# Processing Record 31 of Set 10 | rosario oeste
# Processing Record 32 of Set 10 | barao de melgaco
# Processing Record 33 of Set 10 | moen
# Processing Record 34 of Set 10 | xudat
# Processing Record 35 of Set 10 | tomatlan
# Processing Record 36 of Set 10 | ariquemes
# Processing Record 37 of Set 10 | vardo
# Processing Record 38 of Set 10 | orsha
# Processing Record 39 of Set 10 | gorshechnoye
# Processing Record 40 of Set 10 | tupelo
# Processing Record 41 of Set 10 | abu samrah
# Processing Record 42 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 43 of Set 10 | los llanos de aridane
# Processing Record 44 of Set 10 | ushtobe
# Processing Record 45 of Set 10 | zhoucheng
# Processing Record 46 of Set 10 | juneau
# Processing Record 47 of Set 10 | sorland
# Processing Record 48 of Set 10 | mareeba
# Processing Record 49 of Set 10 | ginir
# Processing Record 50 of Set 10 | deming
# Processing Record 1 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 11 | uvinza
# Processing Record 3 of Set 11 | puerto maldonado
# Processing Record 4 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 5 of Set 11 | sarwar
# Processing Record 6 of Set 11 | caluquembe
# Processing Record 7 of Set 11 | ust-kuyga
# Processing Record 8 of Set 11 | shelburne
# Processing Record 9 of Set 11 | janow lubelski
# Processing Record 10 of Set 11 | sai buri
# Processing Record 11 of Set 11 | atar
# Processing Record 12 of Set 11 | dicabisagan
# Processing Record 13 of Set 11 | nara
# Processing Record 14 of Set 11 | tahta
# Processing Record 15 of Set 11 | cantaura
# Processing Record 16 of Set 11 | mocuba
# Processing Record 17 of Set 11 | evanston
# Processing Record 18 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 19 of Set 11 | tonaya
# Processing Record 20 of Set 11 | liepaja
# Processing Record 21 of Set 11 | baherden
# Processing Record 22 of Set 11 | vidim
# Processing Record 23 of Set 11 | sukhumi
# Processing Record 24 of Set 11 | danielskuil
# Processing Record 25 of Set 11 | urengoy
# Processing Record 26 of Set 11 | yumen
# Processing Record 27 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 11 | allen
# Processing Record 29 of Set 11 | oktyabrskiy
# Processing Record 30 of Set 11 | vyyezdnoye
# Processing Record 31 of Set 11 | prabumulih
# Processing Record 32 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 11 | kathu
# Processing Record 34 of Set 11 | kampot
# Processing Record 35 of Set 11 | zhigansk
# Processing Record 36 of Set 11 | mangrol
# Processing Record 37 of Set 11 | vestmannaeyjar
# Processing Record 38 of Set 11 | maragogi
# Processing Record 39 of Set 11 | nabire
# Processing Record 40 of Set 11 | aklavik
# Processing Record 41 of Set 11 | gat
# Processing Record 42 of Set 11 | komadi
# Processing Record 43 of Set 11 | salinopolis
# Processing Record 44 of Set 11 | rocha
# Processing Record 45 of Set 11 | vostok
# Processing Record 46 of Set 11 | itarema
# Processing Record 47 of Set 11 | nhulunbuy
# Processing Record 48 of Set 11 | ahuimanu
# Processing Record 49 of Set 11 | peleduy
# Processing Record 50 of Set 11 | nanakuli
# Processing Record 1 of Set 12 | deh rawud
# City not found. Skipping...
# Processing Record 2 of Set 12 | beira
# Processing Record 3 of Set 12 | chifeng
# Processing Record 4 of Set 12 | kigorobya
# Processing Record 5 of Set 12 | tevaitoa
# Processing Record 6 of Set 12 | kawalu
# Processing Record 7 of Set 12 | nabisar
# Processing Record 8 of Set 12 | pozo colorado
# Processing Record 9 of Set 12 | krasnoborsk
# Processing Record 10 of Set 12 | amarillo
# Processing Record 11 of Set 12 | constitucion
# Processing Record 12 of Set 12 | qasigiannguit
# Processing Record 13 of Set 12 | camacha
# Processing Record 14 of Set 12 | tulagi
# Processing Record 15 of Set 12 | khor
# Processing Record 16 of Set 12 | maha sarakham
# Processing Record 17 of Set 12 | santiago del estero
# Processing Record 18 of Set 12 | sitka
# Processing Record 19 of Set 12 | bridlington
# Processing Record 20 of Set 12 | bud
# Processing Record 21 of Set 12 | kerema
# Processing Record 22 of Set 12 | belmonte
# Processing Record 23 of Set 12 | miki
# Processing Record 24 of Set 12 | luzon
# Processing Record 25 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 12 | shakiso
# Processing Record 27 of Set 12 | liverpool
# Processing Record 28 of Set 12 | orlik
# Processing Record 29 of Set 12 | nelson bay
# Processing Record 30 of Set 12 | thongwa
# Processing Record 31 of Set 12 | ajdabiya
# Processing Record 32 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 33 of Set 12 | ranot
# Processing Record 34 of Set 12 | saint-pierre
# Processing Record 35 of Set 12 | dhidhdhoo
# Processing Record 36 of Set 12 | ancud
# Processing Record 37 of Set 12 | terney
# Processing Record 38 of Set 12 | tonantins
# Processing Record 39 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 12 | usinsk
# Processing Record 42 of Set 12 | escanaba
# Processing Record 43 of Set 12 | meulaboh
# Processing Record 44 of Set 12 | blackfoot
# Processing Record 45 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 46 of Set 12 | pimenta bueno
# Processing Record 47 of Set 12 | bonavista
# Processing Record 48 of Set 12 | khasan
# Processing Record 49 of Set 12 | brewster
# Processing Record 50 of Set 12 | khvorostyanka
# Processing Record 1 of Set 13 | alpena
# Processing Record 2 of Set 13 | shouguang
# Processing Record 3 of Set 13 | koygorodok
# Processing Record 4 of Set 13 | xichang
# Processing Record 5 of Set 13 | taoudenni
# Processing Record 6 of Set 13 | abnub
# Processing Record 7 of Set 13 | kieta
# Processing Record 8 of Set 13 | dumas
# Processing Record 9 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 10 of Set 13 | antofagasta
# Processing Record 11 of Set 13 | kachiry
# Processing Record 12 of Set 13 | katima mulilo
# Processing Record 13 of Set 13 | qom
# Processing Record 14 of Set 13 | souillac
# Processing Record 15 of Set 13 | hofn
# Processing Record 16 of Set 13 | bambanglipuro
# Processing Record 17 of Set 13 | milkovo
# Processing Record 18 of Set 13 | waynesboro
# Processing Record 19 of Set 13 | solok
# Processing Record 20 of Set 13 | huanren
# Processing Record 21 of Set 13 | betioky
# Processing Record 22 of Set 13 | mabaruma
# Processing Record 23 of Set 13 | macamic
# Processing Record 24 of Set 13 | sao felix do xingu
# Processing Record 25 of Set 13 | manati
# Processing Record 26 of Set 13 | westport
# Processing Record 27 of Set 13 | saint-leu
# Processing Record 28 of Set 13 | halifax
# Processing Record 29 of Set 13 | tazmalt
# Processing Record 30 of Set 13 | yarovoye
# Processing Record 31 of Set 13 | amahai
# Processing Record 32 of Set 13 | balad
# Processing Record 33 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 34 of Set 13 | robinson
# Processing Record 35 of Set 13 | mildmay
# Processing Record 36 of Set 13 | shenjiamen
# Processing Record 37 of Set 13 | ippy
# Processing Record 38 of Set 13 | shamary
# Processing Record 39 of Set 13 | havoysund
# Processing Record 40 of Set 13 | adre
# Processing Record 41 of Set 13 | polis
# Processing Record 42 of Set 13 | senanga
# Processing Record 43 of Set 13 | ilabaya
# Processing Record 44 of Set 13 | hualmay
# Processing Record 45 of Set 13 | san patricio
# Processing Record 46 of Set 13 | jiazi
# Processing Record 47 of Set 13 | jalu
# Processing Record 48 of Set 13 | isla vista
# Processing Record 49 of Set 13 | kabalo
# Processing Record 50 of Set 13 | ola
# Processing Record 1 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 2 of Set 14 | manutuke
# Processing Record 3 of Set 14 | moerai
# Processing Record 4 of Set 14 | benguela
# Processing Record 5 of Set 14 | igarka
# Processing Record 6 of Set 14 | korem
# Processing Record 7 of Set 14 | oum hadjer
# Processing Record 8 of Set 14 | ayame
# Processing Record 9 of Set 14 | uige
# Processing Record 10 of Set 14 | fairbanks
# Processing Record 11 of Set 14 | marburg
# Processing Record 12 of Set 14 | kautokeino
# Processing Record 13 of Set 14 | raisinghnagar
# Processing Record 14 of Set 14 | leshukonskoye
# Processing Record 15 of Set 14 | wake forest
# Processing Record 16 of Set 14 | aktash
# Processing Record 17 of Set 14 | gizo
# Processing Record 18 of Set 14 | puerto el triunfo
# Processing Record 19 of Set 14 | toungoo
# City not found. Skipping...
# Processing Record 20 of Set 14 | mapiri
# Processing Record 21 of Set 14 | newport
# Processing Record 22 of Set 14 | tottori
# Processing Record 23 of Set 14 | padang
# Processing Record 24 of Set 14 | warrington
# Processing Record 25 of Set 14 | whitehorse
# Processing Record 26 of Set 14 | skibbereen
# Processing Record 27 of Set 14 | shellbrook
# Processing Record 28 of Set 14 | arang
# Processing Record 29 of Set 14 | lima
# Processing Record 30 of Set 14 | hot springs
# Processing Record 31 of Set 14 | villa guerrero
# Processing Record 32 of Set 14 | palana
# Processing Record 33 of Set 14 | south lake tahoe
# Processing Record 34 of Set 14 | am timan
# Processing Record 35 of Set 14 | bulgan
# Processing Record 36 of Set 14 | muragachha
# City not found. Skipping...
# Processing Record 37 of Set 14 | werda
# Processing Record 38 of Set 14 | malibu
# Processing Record 39 of Set 14 | ban bung
# Processing Record 40 of Set 14 | bergheim
# Processing Record 41 of Set 14 | lahaina
# Processing Record 42 of Set 14 | pahrump
# Processing Record 43 of Set 14 | lephepe
# City not found. Skipping...
# Processing Record 44 of Set 14 | xinqing
# Processing Record 45 of Set 14 | veinticinco de mayo
# Processing Record 46 of Set 14 | san andres
# Processing Record 47 of Set 14 | san policarpo
# Processing Record 48 of Set 14 | rio grande
# Processing Record 49 of Set 14 | acapulco
# Processing Record 50 of Set 14 | port blair
# Processing Record 1 of Set 15 | basco
# Processing Record 2 of Set 15 | omboue
# Processing Record 3 of Set 15 | smithers
# Processing Record 4 of Set 15 | huitziltepec
# Processing Record 5 of Set 15 | chumikan
# Processing Record 6 of Set 15 | lenggries
# Processing Record 7 of Set 15 | granada
# Processing Record 8 of Set 15 | cadillac
# Processing Record 9 of Set 15 | sabha
# Processing Record 10 of Set 15 | san-pedro
# Processing Record 11 of Set 15 | agadez
# Processing Record 12 of Set 15 | anjozorobe
# Processing Record 13 of Set 15 | filadelfia
# Processing Record 14 of Set 15 | tautira
# Processing Record 15 of Set 15 | lincoln
# Processing Record 16 of Set 15 | myitkyina
# Processing Record 17 of Set 15 | hermagor
# Processing Record 18 of Set 15 | poum
# Processing Record 19 of Set 15 | zhezkazgan
# Processing Record 20 of Set 15 | sharjah
# Processing Record 21 of Set 15 | birobidzhan
# Processing Record 22 of Set 15 | bafia
# Processing Record 23 of Set 15 | tupiza
# Processing Record 24 of Set 15 | solnechnyy
# Processing Record 25 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 15 | kaspiyskiy
# Processing Record 27 of Set 15 | lar gerd
# City not found. Skipping...
# Processing Record 28 of Set 15 | bairiki
# Processing Record 29 of Set 15 | concarneau
# Processing Record 30 of Set 15 | kulhudhuffushi
# Processing Record 31 of Set 15 | pokhara
# Processing Record 32 of Set 15 | holetown
# Processing Record 33 of Set 15 | lata
# Processing Record 34 of Set 15 | teahupoo
# Processing Record 35 of Set 15 | mnogovershinnyy
# Processing Record 36 of Set 15 | diamantino
# Processing Record 37 of Set 15 | sisimiut
# Processing Record 38 of Set 15 | omaruru
# Processing Record 39 of Set 15 | klyuchi
# Processing Record 40 of Set 15 | kodinsk
# Processing Record 41 of Set 15 | hay river
# Processing Record 42 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 43 of Set 15 | chilca
# Processing Record 44 of Set 15 | glasgow
# Processing Record 45 of Set 15 | dalvik
# Processing Record 46 of Set 15 | log
# Processing Record 47 of Set 15 | oksfjord
# Processing Record 48 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 49 of Set 15 | merauke
# Processing Record 50 of Set 15 | abu kamal
# Processing Record 1 of Set 16 | nobres
# Processing Record 2 of Set 16 | ormara
# Processing Record 3 of Set 16 | forestville
# Processing Record 4 of Set 16 | biltine
# Processing Record 5 of Set 16 | baturaja
# Processing Record 6 of Set 16 | cheuskiny
# City not found. Skipping...
# Processing Record 7 of Set 16 | sur
# Processing Record 8 of Set 16 | quelimane
# Processing Record 9 of Set 16 | panorama
# Processing Record 10 of Set 16 | rauma
# Processing Record 11 of Set 16 | jumla
# Processing Record 12 of Set 16 | merke
# Processing Record 13 of Set 16 | gobabis
# Processing Record 14 of Set 16 | cidreira
# Processing Record 15 of Set 16 | chara
# Processing Record 16 of Set 16 | port-cartier
# Processing Record 17 of Set 16 | kalabo
# Processing Record 18 of Set 16 | balkhash
# Processing Record 19 of Set 16 | nuuk
# Processing Record 20 of Set 16 | ketchikan
# Processing Record 21 of Set 16 | port-gentil
# Processing Record 22 of Set 16 | polyarnyy
# Processing Record 23 of Set 16 | alta gracia
# Processing Record 24 of Set 16 | pisco
# Processing Record 25 of Set 16 | goundam
# Processing Record 26 of Set 16 | samana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of dictionairies to a DataFrame.
city_data_df =  pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp Current Description  \
# 0    Port Elizabeth -33.9180   25.5701     61.09    scattered clouds
# 1            Hobart -42.8794  147.3294     57.02       broken clouds
# 2        Wilmington  34.2257  -77.9447     77.95           clear sky
# 3         Busselton -33.6500  115.3333     44.10           clear sky
# 4        Uruguaiana -29.7547  -57.0883     64.33          light rain
# ..              ...      ...       ...       ...                 ...
# 710       Polyarnyy  69.1989   33.4478     32.47    scattered clouds
# 711     Alta Gracia -31.6529  -64.4283     75.88           clear sky
# 712           Pisco -13.7000  -76.2167     64.45           clear sky
# 713         Goundam  16.4145   -3.6708     91.85           clear sky
# 714          Samana  19.2056  -69.3369     82.62          light rain
#
#      Humidity  Cloudiness  Wind Speed Country
# 0          94          40       10.36      ZA
# 1          88          75        9.22      AU
# 2          72           1        8.05      US
# 3          86           0       10.31      AU
# 4          88          75       17.27      BR
# ..        ...         ...         ...     ...
# 710        84          45       12.62      RU
# 711        53           4        8.75      AR
# 712        77           0       19.57      PE
# 713         9           2        9.08      ML
# 714        78          75        4.61      DO
#
# [715 rows x 9 columns]

# %%
cd Weather_Database
# Out:
# /Users/joepizz/Desktop/Weather_Database

# %%
# Create the output file (CSV)
output_data_file = "_pycache_/cities.csv"
# Export the City_data to a csv
city_data_df.to_csv(output_data_file, index_label= "City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-cbd56b0ced74> in <module>
#       2 output_data_file = "_pycache_/cities.csv"
#       3 # Export the City_data to a csv
# ----> 4 city_data_df.to_csv(output_data_file, index_label= "City_ID")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '_pycache_/cities.csv'
